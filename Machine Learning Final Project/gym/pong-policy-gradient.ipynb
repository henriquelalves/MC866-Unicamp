# %%
""" Trains an agent with (stochastic) Policy Gradients on Pong. Uses OpenAI Gym. """
import numpy as np
import gym

# hyperparameters
H = 200 # number of hidden layer neurons
batch_size = 10 # every how many episodes to do a param update?
learning_rate = 1e-4
gamma = 0.99 # discount factor for reward
decay_rate = 0.99 # decay factor for RMSProp leaky sum of grad^2
resume = False # resume from previous checkpoint?
render = True

# model initialization
D = 80 * 80 # input dimensionality: 80x80 grid

model = {}
model['W1'] = np.random.randn(H,D) / np.sqrt(D) # "Xavier" initialization
model['W2'] = np.random.randn(H) / np.sqrt(H)

print(model['W1'].shape)
print(model['W2'].shape)

grad_buffer = { k : np.zeros_like(v) for k,v in model.items() } # update buffers that add up gradients over a batch
rmsprop_cache = { k : np.zeros_like(v) for k,v in model.items() } # rmsprop memory

def sigmoid(x): 
    return 1.0 / (1.0 + np.exp(-x)) # sigmoid "squashing" function to interval [0,1]

def prepro(I):
    """ prepro 210x160x3 uint8 frame into 6400 (80x80) 1D float vector """
    I = I[35:195] # crop
    I = I[::2,::2,0] # downsample by factor of 2
    I[I == 144] = 0 # erase background (background type 1)
    I[I == 109] = 0 # erase background (background type 2)
    I[I != 0] = 1 # everything else (paddles, ball) just set to 1
    return I.astype(np.float).ravel()

def discount_rewards(r):
    """ take 1D float array of rewards and compute discounted reward """
    discounted_r = np.zeros_like(r)
    running_add = 0
    for t in reversed(range(0, r.size)):
        if r[t] != 0: running_add = 0 # reset the sum, since this was a game boundary (pong specific!)
        running_add = running_add * gamma + r[t]
        discounted_r[t] = running_add
    return discounted_r

def policy_forward(x):
    h = np.dot(model['W1'], x)
    h[h<0] = 0 # ReLU nonlinearity
    logp = np.dot(model['W2'], h)
    p = sigmoid(logp)
    return p, h # return probability of taking action 2, and hidden state

def policy_backward(eph, epdlogp):
    """ backward pass. (eph is array of intermediate hidden states) """
    dW2 = np.dot(eph.T, epdlogp).ravel()
    dh = np.outer(epdlogp, model['W2'])
    dh[eph <= 0] = 0 # backpro prelu
    dW1 = np.dot(dh.T, epx)
    return {'W1':dW1, 'W2':dW2}
# Out:
# (200, 6400)
# (200,)

# %%
env = gym.make("Pong-v0")
observation = env.reset()
prev_x = None # used in computing the difference frame
xs,hs,dlogps,drs = [],[],[],[]
running_reward = None
reward_sum = 0
episode_number = 0
while True:
    if render: env.render()

    # preprocess the observation, set input to network to be difference image
    cur_x = prepro(observation)
    x = cur_x - prev_x if prev_x is not None else np.zeros(D)
    prev_x = cur_x

    # forward the policy network and sample an action from the returned probability
    aprob, h = policy_forward(x)
    action = 2 if np.random.uniform() < aprob else 3 # roll the dice!

    # record various intermediates (needed later for backprop)
    xs.append(x) # observation
    hs.append(h) # hidden state
    y = 1 if action == 2 else 0 # a "fake label"
    dlogps.append(y - aprob) # grad that encourages the action that was taken to be taken (see http://cs231n.github.io/neural-networks-2/#losses if confused)

    # step the environment and get new measurements
    observation, reward, done, info = env.step(action)
    reward_sum += reward

    drs.append(reward) # record reward (has to be done after we call step() to get reward for previous action)

    if done: # an episode finished
        episode_number += 1

        # stack together all inputs, hidden states, action gradients, and rewards for this episode
        epx = np.vstack(xs)
        eph = np.vstack(hs)
        epdlogp = np.vstack(dlogps)
        epr = np.vstack(drs)
        xs,hs,dlogps,drs = [],[],[],[] # reset array memory

        # compute the discounted reward backwards through time
        discounted_epr = discount_rewards(epr)
        # standardize the rewards to be unit normal (helps control the gradient estimator variance)
        discounted_epr -= np.mean(discounted_epr)
        discounted_epr /= np.std(discounted_epr)

        epdlogp *= discounted_epr # modulate the gradient with advantage (PG magic happens right here.)
        grad = policy_backward(eph, epdlogp)
        for k in model: grad_buffer[k] += grad[k] # accumulate grad over batch

        # perform rmsprop parameter update every batch_size episodes
        if episode_number % batch_size == 0:
            for k,v in model.items():
                g = grad_buffer[k] # gradient
                rmsprop_cache[k] = decay_rate * rmsprop_cache[k] + (1 - decay_rate) * g**2
                model[k] += learning_rate * g / (np.sqrt(rmsprop_cache[k]) + 1e-5)
                grad_buffer[k] = np.zeros_like(v) # reset batch gradient buffer

        # boring book-keeping
        running_reward = reward_sum if running_reward is None else running_reward * 0.99 + reward_sum * 0.01
        print('resetting env. episode reward total was %f. running mean: %f' % (reward_sum, running_reward))
        #if episode_number % 100 == 0: pickle.dump(model, open('save.p', 'wb'))
        reward_sum = 0
        observation = env.reset() # reset env
        prev_x = None
# Out:
# resetting env. episode reward total was -21.000000. running mean: -21.000000
# resetting env. episode reward total was -21.000000. running mean: -21.000000
# resetting env. episode reward total was -21.000000. running mean: -21.000000
# resetting env. episode reward total was -21.000000. running mean: -21.000000
# resetting env. episode reward total was -21.000000. running mean: -21.000000
# resetting env. episode reward total was -21.000000. running mean: -21.000000
# resetting env. episode reward total was -21.000000. running mean: -21.000000
# resetting env. episode reward total was -21.000000. running mean: -21.000000
# resetting env. episode reward total was -21.000000. running mean: -21.000000
# resetting env. episode reward total was -21.000000. running mean: -21.000000
# resetting env. episode reward total was -21.000000. running mean: -21.000000
# resetting env. episode reward total was -21.000000. running mean: -21.000000
# resetting env. episode reward total was -21.000000. running mean: -21.000000
# resetting env. episode reward total was -21.000000. running mean: -21.000000
# resetting env. episode reward total was -19.000000. running mean: -20.980000
# resetting env. episode reward total was -21.000000. running mean: -20.980200
# resetting env. episode reward total was -19.000000. running mean: -20.960398
# resetting env. episode reward total was -21.000000. running mean: -20.960794
# resetting env. episode reward total was -21.000000. running mean: -20.961186
# resetting env. episode reward total was -21.000000. running mean: -20.961574
# resetting env. episode reward total was -21.000000. running mean: -20.961958
# resetting env. episode reward total was -21.000000. running mean: -20.962339
# resetting env. episode reward total was -21.000000. running mean: -20.962716
# resetting env. episode reward total was -21.000000. running mean: -20.963088
# resetting env. episode reward total was -21.000000. running mean: -20.963457
# resetting env. episode reward total was -21.000000. running mean: -20.963823
# resetting env. episode reward total was -21.000000. running mean: -20.964185
# resetting env. episode reward total was -20.000000. running mean: -20.954543
# resetting env. episode reward total was -21.000000. running mean: -20.954997
# resetting env. episode reward total was -21.000000. running mean: -20.955447
# resetting env. episode reward total was -21.000000. running mean: -20.955893
# resetting env. episode reward total was -21.000000. running mean: -20.956334
# resetting env. episode reward total was -21.000000. running mean: -20.956771
# resetting env. episode reward total was -20.000000. running mean: -20.947203
# resetting env. episode reward total was -21.000000. running mean: -20.947731
# resetting env. episode reward total was -19.000000. running mean: -20.928254
# resetting env. episode reward total was -20.000000. running mean: -20.918971
# resetting env. episode reward total was -21.000000. running mean: -20.919781
# resetting env. episode reward total was -21.000000. running mean: -20.920584
# resetting env. episode reward total was -21.000000. running mean: -20.921378
# resetting env. episode reward total was -20.000000. running mean: -20.912164
# resetting env. episode reward total was -19.000000. running mean: -20.893042
# resetting env. episode reward total was -21.000000. running mean: -20.894112
# resetting env. episode reward total was -21.000000. running mean: -20.895171
# resetting env. episode reward total was -20.000000. running mean: -20.886219
# resetting env. episode reward total was -21.000000. running mean: -20.887357
# resetting env. episode reward total was -21.000000. running mean: -20.888483
# resetting env. episode reward total was -21.000000. running mean: -20.889598
# resetting env. episode reward total was -21.000000. running mean: -20.890702
# resetting env. episode reward total was -21.000000. running mean: -20.891795
# resetting env. episode reward total was -17.000000. running mean: -20.852878
# resetting env. episode reward total was -21.000000. running mean: -20.854349
# resetting env. episode reward total was -21.000000. running mean: -20.855805
# resetting env. episode reward total was -19.000000. running mean: -20.837247
# resetting env. episode reward total was -18.000000. running mean: -20.808875
# resetting env. episode reward total was -21.000000. running mean: -20.810786
# resetting env. episode reward total was -21.000000. running mean: -20.812678
# resetting env. episode reward total was -18.000000. running mean: -20.784551
# resetting env. episode reward total was -20.000000. running mean: -20.776706
# resetting env. episode reward total was -21.000000. running mean: -20.778939
# resetting env. episode reward total was -21.000000. running mean: -20.781149
# resetting env. episode reward total was -21.000000. running mean: -20.783338
# resetting env. episode reward total was -21.000000. running mean: -20.785504
# resetting env. episode reward total was -21.000000. running mean: -20.787649
# resetting env. episode reward total was -21.000000. running mean: -20.789773
# resetting env. episode reward total was -21.000000. running mean: -20.791875
# resetting env. episode reward total was -20.000000. running mean: -20.783956
# resetting env. episode reward total was -19.000000. running mean: -20.766117
# resetting env. episode reward total was -21.000000. running mean: -20.768456
# resetting env. episode reward total was -21.000000. running mean: -20.770771
# resetting env. episode reward total was -21.000000. running mean: -20.773063
# resetting env. episode reward total was -21.000000. running mean: -20.775333
# resetting env. episode reward total was -20.000000. running mean: -20.767580
# resetting env. episode reward total was -20.000000. running mean: -20.759904
# resetting env. episode reward total was -21.000000. running mean: -20.762305
# resetting env. episode reward total was -21.000000. running mean: -20.764682
# resetting env. episode reward total was -19.000000. running mean: -20.747035
# resetting env. episode reward total was -21.000000. running mean: -20.749564
# resetting env. episode reward total was -20.000000. running mean: -20.742069
# resetting env. episode reward total was -20.000000. running mean: -20.734648
# resetting env. episode reward total was -21.000000. running mean: -20.737302
# resetting env. episode reward total was -21.000000. running mean: -20.739929
# resetting env. episode reward total was -21.000000. running mean: -20.742529
# resetting env. episode reward total was -21.000000. running mean: -20.745104
# resetting env. episode reward total was -21.000000. running mean: -20.747653
# resetting env. episode reward total was -21.000000. running mean: -20.750176
# resetting env. episode reward total was -20.000000. running mean: -20.742675
# resetting env. episode reward total was -20.000000. running mean: -20.735248
# resetting env. episode reward total was -19.000000. running mean: -20.717895
# resetting env. episode reward total was -21.000000. running mean: -20.720717
# resetting env. episode reward total was -19.000000. running mean: -20.703509
# resetting env. episode reward total was -20.000000. running mean: -20.696474
# resetting env. episode reward total was -20.000000. running mean: -20.689510
# resetting env. episode reward total was -20.000000. running mean: -20.682614
# resetting env. episode reward total was -21.000000. running mean: -20.685788
# resetting env. episode reward total was -21.000000. running mean: -20.688930
# resetting env. episode reward total was -19.000000. running mean: -20.672041
# resetting env. episode reward total was -19.000000. running mean: -20.655321
# resetting env. episode reward total was -21.000000. running mean: -20.658767
# resetting env. episode reward total was -21.000000. running mean: -20.662180
# resetting env. episode reward total was -21.000000. running mean: -20.665558
# resetting env. episode reward total was -20.000000. running mean: -20.658902
# resetting env. episode reward total was -21.000000. running mean: -20.662313
# resetting env. episode reward total was -21.000000. running mean: -20.665690
# resetting env. episode reward total was -21.000000. running mean: -20.669033
# resetting env. episode reward total was -21.000000. running mean: -20.672343
# resetting env. episode reward total was -21.000000. running mean: -20.675620
# resetting env. episode reward total was -17.000000. running mean: -20.638863
# resetting env. episode reward total was -20.000000. running mean: -20.632475
# resetting env. episode reward total was -21.000000. running mean: -20.636150
# resetting env. episode reward total was -20.000000. running mean: -20.629789
# resetting env. episode reward total was -21.000000. running mean: -20.633491
# resetting env. episode reward total was -20.000000. running mean: -20.627156
# resetting env. episode reward total was -21.000000. running mean: -20.630884
# resetting env. episode reward total was -21.000000. running mean: -20.634575
# resetting env. episode reward total was -20.000000. running mean: -20.628230
# resetting env. episode reward total was -21.000000. running mean: -20.631947
# resetting env. episode reward total was -20.000000. running mean: -20.625628
# resetting env. episode reward total was -20.000000. running mean: -20.619372
# resetting env. episode reward total was -21.000000. running mean: -20.623178
# resetting env. episode reward total was -21.000000. running mean: -20.626946
# resetting env. episode reward total was -19.000000. running mean: -20.610677
# resetting env. episode reward total was -20.000000. running mean: -20.604570
# resetting env. episode reward total was -20.000000. running mean: -20.598524
# resetting env. episode reward total was -21.000000. running mean: -20.602539
# resetting env. episode reward total was -21.000000. running mean: -20.606513
# resetting env. episode reward total was -21.000000. running mean: -20.610448
# resetting env. episode reward total was -20.000000. running mean: -20.604344
# resetting env. episode reward total was -21.000000. running mean: -20.608300
# resetting env. episode reward total was -21.000000. running mean: -20.612217
# resetting env. episode reward total was -21.000000. running mean: -20.616095
# resetting env. episode reward total was -20.000000. running mean: -20.609934
# resetting env. episode reward total was -21.000000. running mean: -20.613835
# resetting env. episode reward total was -21.000000. running mean: -20.617697
# resetting env. episode reward total was -21.000000. running mean: -20.621520
# resetting env. episode reward total was -21.000000. running mean: -20.625304
# resetting env. episode reward total was -21.000000. running mean: -20.629051
# resetting env. episode reward total was -21.000000. running mean: -20.632761
# resetting env. episode reward total was -21.000000. running mean: -20.636433
# resetting env. episode reward total was -21.000000. running mean: -20.640069
# resetting env. episode reward total was -21.000000. running mean: -20.643668
# resetting env. episode reward total was -21.000000. running mean: -20.647232
# resetting env. episode reward total was -21.000000. running mean: -20.650759
# resetting env. episode reward total was -21.000000. running mean: -20.654252
# resetting env. episode reward total was -21.000000. running mean: -20.657709
# resetting env. episode reward total was -20.000000. running mean: -20.651132
# resetting env. episode reward total was -20.000000. running mean: -20.644621
# resetting env. episode reward total was -19.000000. running mean: -20.628175
# resetting env. episode reward total was -21.000000. running mean: -20.631893
# resetting env. episode reward total was -21.000000. running mean: -20.635574
# resetting env. episode reward total was -21.000000. running mean: -20.639218
# resetting env. episode reward total was -19.000000. running mean: -20.622826
# resetting env. episode reward total was -20.000000. running mean: -20.616598
# resetting env. episode reward total was -20.000000. running mean: -20.610432
# resetting env. episode reward total was -21.000000. running mean: -20.614327
# resetting env. episode reward total was -20.000000. running mean: -20.608184
# resetting env. episode reward total was -21.000000. running mean: -20.612102
# resetting env. episode reward total was -20.000000. running mean: -20.605981
# resetting env. episode reward total was -21.000000. running mean: -20.609921
# resetting env. episode reward total was -21.000000. running mean: -20.613822
# resetting env. episode reward total was -21.000000. running mean: -20.617684
# resetting env. episode reward total was -20.000000. running mean: -20.611507
# resetting env. episode reward total was -21.000000. running mean: -20.615392
# resetting env. episode reward total was -21.000000. running mean: -20.619238
# resetting env. episode reward total was -20.000000. running mean: -20.613046
# resetting env. episode reward total was -19.000000. running mean: -20.596915
# resetting env. episode reward total was -21.000000. running mean: -20.600946
# resetting env. episode reward total was -20.000000. running mean: -20.594937
# resetting env. episode reward total was -20.000000. running mean: -20.588987
# resetting env. episode reward total was -21.000000. running mean: -20.593097
# resetting env. episode reward total was -20.000000. running mean: -20.587166
# resetting env. episode reward total was -20.000000. running mean: -20.581295
# resetting env. episode reward total was -21.000000. running mean: -20.585482
# resetting env. episode reward total was -20.000000. running mean: -20.579627
# resetting env. episode reward total was -21.000000. running mean: -20.583831
# resetting env. episode reward total was -20.000000. running mean: -20.577992
# resetting env. episode reward total was -21.000000. running mean: -20.582213
# resetting env. episode reward total was -20.000000. running mean: -20.576390
# resetting env. episode reward total was -20.000000. running mean: -20.570627
# resetting env. episode reward total was -21.000000. running mean: -20.574920
# resetting env. episode reward total was -21.000000. running mean: -20.579171
# resetting env. episode reward total was -20.000000. running mean: -20.573379
# resetting env. episode reward total was -21.000000. running mean: -20.577646
# resetting env. episode reward total was -21.000000. running mean: -20.581869
# resetting env. episode reward total was -21.000000. running mean: -20.586050
# resetting env. episode reward total was -21.000000. running mean: -20.590190
# resetting env. episode reward total was -21.000000. running mean: -20.594288
# resetting env. episode reward total was -21.000000. running mean: -20.598345
# resetting env. episode reward total was -21.000000. running mean: -20.602362
# resetting env. episode reward total was -20.000000. running mean: -20.596338
# resetting env. episode reward total was -21.000000. running mean: -20.600375
# resetting env. episode reward total was -20.000000. running mean: -20.594371
# resetting env. episode reward total was -18.000000. running mean: -20.568427
# resetting env. episode reward total was -21.000000. running mean: -20.572743
# resetting env. episode reward total was -21.000000. running mean: -20.577016
# resetting env. episode reward total was -21.000000. running mean: -20.581245
# resetting env. episode reward total was -21.000000. running mean: -20.585433
# resetting env. episode reward total was -20.000000. running mean: -20.579579
# resetting env. episode reward total was -21.000000. running mean: -20.583783
# resetting env. episode reward total was -21.000000. running mean: -20.587945
# resetting env. episode reward total was -21.000000. running mean: -20.592066
# resetting env. episode reward total was -20.000000. running mean: -20.586145
# resetting env. episode reward total was -20.000000. running mean: -20.580283
# resetting env. episode reward total was -20.000000. running mean: -20.574481
# resetting env. episode reward total was -21.000000. running mean: -20.578736
# resetting env. episode reward total was -20.000000. running mean: -20.572948
# resetting env. episode reward total was -19.000000. running mean: -20.557219
# resetting env. episode reward total was -21.000000. running mean: -20.561647
# resetting env. episode reward total was -21.000000. running mean: -20.566030
# resetting env. episode reward total was -21.000000. running mean: -20.570370
# resetting env. episode reward total was -21.000000. running mean: -20.574666
# resetting env. episode reward total was -20.000000. running mean: -20.568920
# resetting env. episode reward total was -20.000000. running mean: -20.563230
# resetting env. episode reward total was -19.000000. running mean: -20.547598
# resetting env. episode reward total was -21.000000. running mean: -20.552122
# resetting env. episode reward total was -21.000000. running mean: -20.556601
# resetting env. episode reward total was -21.000000. running mean: -20.561035
# resetting env. episode reward total was -20.000000. running mean: -20.555425
# resetting env. episode reward total was -20.000000. running mean: -20.549870
# resetting env. episode reward total was -20.000000. running mean: -20.544372
# resetting env. episode reward total was -21.000000. running mean: -20.548928
# resetting env. episode reward total was -19.000000. running mean: -20.533439
# resetting env. episode reward total was -21.000000. running mean: -20.538104
# resetting env. episode reward total was -18.000000. running mean: -20.512723
# resetting env. episode reward total was -21.000000. running mean: -20.517596
# resetting env. episode reward total was -20.000000. running mean: -20.512420
# resetting env. episode reward total was -21.000000. running mean: -20.517296
# resetting env. episode reward total was -21.000000. running mean: -20.522123
# resetting env. episode reward total was -21.000000. running mean: -20.526902
# resetting env. episode reward total was -20.000000. running mean: -20.521633
# resetting env. episode reward total was -21.000000. running mean: -20.526416
# resetting env. episode reward total was -21.000000. running mean: -20.531152
# resetting env. episode reward total was -21.000000. running mean: -20.535841
# resetting env. episode reward total was -21.000000. running mean: -20.540482
# resetting env. episode reward total was -21.000000. running mean: -20.545077
# resetting env. episode reward total was -20.000000. running mean: -20.539627
# resetting env. episode reward total was -21.000000. running mean: -20.544230
# resetting env. episode reward total was -21.000000. running mean: -20.548788
# resetting env. episode reward total was -21.000000. running mean: -20.553300
# resetting env. episode reward total was -21.000000. running mean: -20.557767
# resetting env. episode reward total was -20.000000. running mean: -20.552189
# resetting env. episode reward total was -21.000000. running mean: -20.556668
# resetting env. episode reward total was -21.000000. running mean: -20.561101
# resetting env. episode reward total was -21.000000. running mean: -20.565490
# resetting env. episode reward total was -20.000000. running mean: -20.559835
# resetting env. episode reward total was -21.000000. running mean: -20.564237
# resetting env. episode reward total was -20.000000. running mean: -20.558594
# resetting env. episode reward total was -21.000000. running mean: -20.563008
# resetting env. episode reward total was -20.000000. running mean: -20.557378
# resetting env. episode reward total was -20.000000. running mean: -20.551804
# resetting env. episode reward total was -21.000000. running mean: -20.556286
# resetting env. episode reward total was -21.000000. running mean: -20.560724
# resetting env. episode reward total was -21.000000. running mean: -20.565116
# resetting env. episode reward total was -21.000000. running mean: -20.569465
# resetting env. episode reward total was -21.000000. running mean: -20.573770
# resetting env. episode reward total was -20.000000. running mean: -20.568033
# resetting env. episode reward total was -21.000000. running mean: -20.572352
# resetting env. episode reward total was -21.000000. running mean: -20.576629
# resetting env. episode reward total was -20.000000. running mean: -20.570863
# resetting env. episode reward total was -20.000000. running mean: -20.565154
# resetting env. episode reward total was -21.000000. running mean: -20.569502
# resetting env. episode reward total was -19.000000. running mean: -20.553807
# resetting env. episode reward total was -21.000000. running mean: -20.558269
# resetting env. episode reward total was -21.000000. running mean: -20.562687
# resetting env. episode reward total was -21.000000. running mean: -20.567060
# resetting env. episode reward total was -21.000000. running mean: -20.571389
# resetting env. episode reward total was -21.000000. running mean: -20.575675
# resetting env. episode reward total was -21.000000. running mean: -20.579919
# resetting env. episode reward total was -21.000000. running mean: -20.584119
# resetting env. episode reward total was -21.000000. running mean: -20.588278
# resetting env. episode reward total was -19.000000. running mean: -20.572395
# resetting env. episode reward total was -21.000000. running mean: -20.576671
# resetting env. episode reward total was -21.000000. running mean: -20.580905
# resetting env. episode reward total was -21.000000. running mean: -20.585096
# resetting env. episode reward total was -21.000000. running mean: -20.589245
# resetting env. episode reward total was -20.000000. running mean: -20.583352
# resetting env. episode reward total was -18.000000. running mean: -20.557519
# resetting env. episode reward total was -18.000000. running mean: -20.531944
# resetting env. episode reward total was -21.000000. running mean: -20.536624
# resetting env. episode reward total was -21.000000. running mean: -20.541258
# resetting env. episode reward total was -21.000000. running mean: -20.545845
# resetting env. episode reward total was -19.000000. running mean: -20.530387
# resetting env. episode reward total was -19.000000. running mean: -20.515083
# resetting env. episode reward total was -21.000000. running mean: -20.519932
# resetting env. episode reward total was -21.000000. running mean: -20.524733
# resetting env. episode reward total was -20.000000. running mean: -20.519486
# resetting env. episode reward total was -21.000000. running mean: -20.524291
# resetting env. episode reward total was -20.000000. running mean: -20.519048
# resetting env. episode reward total was -21.000000. running mean: -20.523857
# resetting env. episode reward total was -21.000000. running mean: -20.528619
# resetting env. episode reward total was -21.000000. running mean: -20.533333
# resetting env. episode reward total was -21.000000. running mean: -20.537999
# resetting env. episode reward total was -19.000000. running mean: -20.522619
# resetting env. episode reward total was -20.000000. running mean: -20.517393
# resetting env. episode reward total was -21.000000. running mean: -20.522219
# resetting env. episode reward total was -21.000000. running mean: -20.526997
# resetting env. episode reward total was -20.000000. running mean: -20.521727
# resetting env. episode reward total was -21.000000. running mean: -20.526510
# resetting env. episode reward total was -21.000000. running mean: -20.531245
# resetting env. episode reward total was -21.000000. running mean: -20.535932
# resetting env. episode reward total was -21.000000. running mean: -20.540573
# resetting env. episode reward total was -19.000000. running mean: -20.525167
# resetting env. episode reward total was -21.000000. running mean: -20.529915
# resetting env. episode reward total was -20.000000. running mean: -20.524616
# resetting env. episode reward total was -20.000000. running mean: -20.519370
# resetting env. episode reward total was -19.000000. running mean: -20.504176
# resetting env. episode reward total was -20.000000. running mean: -20.499135
# resetting env. episode reward total was -21.000000. running mean: -20.504143
# resetting env. episode reward total was -20.000000. running mean: -20.499102
# resetting env. episode reward total was -19.000000. running mean: -20.484111
# resetting env. episode reward total was -20.000000. running mean: -20.479270
# resetting env. episode reward total was -21.000000. running mean: -20.484477
# resetting env. episode reward total was -20.000000. running mean: -20.479632
# resetting env. episode reward total was -20.000000. running mean: -20.474836
# resetting env. episode reward total was -21.000000. running mean: -20.480088
# resetting env. episode reward total was -20.000000. running mean: -20.475287
# resetting env. episode reward total was -21.000000. running mean: -20.480534
# resetting env. episode reward total was -20.000000. running mean: -20.475728
# resetting env. episode reward total was -21.000000. running mean: -20.480971
# resetting env. episode reward total was -21.000000. running mean: -20.486161
# resetting env. episode reward total was -21.000000. running mean: -20.491300
# resetting env. episode reward total was -21.000000. running mean: -20.496387
# resetting env. episode reward total was -21.000000. running mean: -20.501423
# resetting env. episode reward total was -18.000000. running mean: -20.476409
# resetting env. episode reward total was -21.000000. running mean: -20.481645
# resetting env. episode reward total was -21.000000. running mean: -20.486828
# resetting env. episode reward total was -20.000000. running mean: -20.481960
# resetting env. episode reward total was -19.000000. running mean: -20.467140
# resetting env. episode reward total was -20.000000. running mean: -20.462469
# resetting env. episode reward total was -20.000000. running mean: -20.457844
# resetting env. episode reward total was -21.000000. running mean: -20.463266
# resetting env. episode reward total was -18.000000. running mean: -20.438633
# resetting env. episode reward total was -21.000000. running mean: -20.444247
# resetting env. episode reward total was -20.000000. running mean: -20.439804
# resetting env. episode reward total was -21.000000. running mean: -20.445406
# resetting env. episode reward total was -21.000000. running mean: -20.450952
# resetting env. episode reward total was -20.000000. running mean: -20.446443
# resetting env. episode reward total was -20.000000. running mean: -20.441978
# resetting env. episode reward total was -21.000000. running mean: -20.447559
# resetting env. episode reward total was -21.000000. running mean: -20.453083
# resetting env. episode reward total was -20.000000. running mean: -20.448552
# resetting env. episode reward total was -20.000000. running mean: -20.444067
# resetting env. episode reward total was -20.000000. running mean: -20.439626
# resetting env. episode reward total was -21.000000. running mean: -20.445230
# resetting env. episode reward total was -20.000000. running mean: -20.440777
# resetting env. episode reward total was -20.000000. running mean: -20.436370
# resetting env. episode reward total was -21.000000. running mean: -20.442006
# resetting env. episode reward total was -21.000000. running mean: -20.447586
# resetting env. episode reward total was -20.000000. running mean: -20.443110
# resetting env. episode reward total was -20.000000. running mean: -20.438679
# resetting env. episode reward total was -20.000000. running mean: -20.434292
# resetting env. episode reward total was -19.000000. running mean: -20.419949
# resetting env. episode reward total was -21.000000. running mean: -20.425750
# resetting env. episode reward total was -21.000000. running mean: -20.431492
# resetting env. episode reward total was -21.000000. running mean: -20.437177
# resetting env. episode reward total was -21.000000. running mean: -20.442805
# resetting env. episode reward total was -19.000000. running mean: -20.428377
# resetting env. episode reward total was -21.000000. running mean: -20.434094
# resetting env. episode reward total was -20.000000. running mean: -20.429753
# resetting env. episode reward total was -21.000000. running mean: -20.435455
# resetting env. episode reward total was -21.000000. running mean: -20.441101
# resetting env. episode reward total was -20.000000. running mean: -20.436690
# resetting env. episode reward total was -21.000000. running mean: -20.442323
# resetting env. episode reward total was -21.000000. running mean: -20.447900
# resetting env. episode reward total was -19.000000. running mean: -20.433421
# resetting env. episode reward total was -21.000000. running mean: -20.439086
# resetting env. episode reward total was -21.000000. running mean: -20.444695
# resetting env. episode reward total was -20.000000. running mean: -20.440248
# resetting env. episode reward total was -20.000000. running mean: -20.435846
# resetting env. episode reward total was -21.000000. running mean: -20.441488
# resetting env. episode reward total was -20.000000. running mean: -20.437073
# resetting env. episode reward total was -20.000000. running mean: -20.432702
# resetting env. episode reward total was -21.000000. running mean: -20.438375
# resetting env. episode reward total was -21.000000. running mean: -20.443991
# resetting env. episode reward total was -21.000000. running mean: -20.449551
# resetting env. episode reward total was -21.000000. running mean: -20.455056
# resetting env. episode reward total was -21.000000. running mean: -20.460505
# resetting env. episode reward total was -21.000000. running mean: -20.465900
# resetting env. episode reward total was -20.000000. running mean: -20.461241
# resetting env. episode reward total was -21.000000. running mean: -20.466629
# resetting env. episode reward total was -21.000000. running mean: -20.471962
# resetting env. episode reward total was -20.000000. running mean: -20.467243
# resetting env. episode reward total was -20.000000. running mean: -20.462570
# resetting env. episode reward total was -21.000000. running mean: -20.467945
# resetting env. episode reward total was -21.000000. running mean: -20.473265
# resetting env. episode reward total was -19.000000. running mean: -20.458533
# resetting env. episode reward total was -20.000000. running mean: -20.453947
# resetting env. episode reward total was -20.000000. running mean: -20.449408
# resetting env. episode reward total was -20.000000. running mean: -20.444914
# resetting env. episode reward total was -20.000000. running mean: -20.440465
# resetting env. episode reward total was -21.000000. running mean: -20.446060
# resetting env. episode reward total was -20.000000. running mean: -20.441599
# resetting env. episode reward total was -21.000000. running mean: -20.447183
# resetting env. episode reward total was -21.000000. running mean: -20.452712
# resetting env. episode reward total was -20.000000. running mean: -20.448184
# resetting env. episode reward total was -20.000000. running mean: -20.443703
# resetting env. episode reward total was -20.000000. running mean: -20.439266
# resetting env. episode reward total was -20.000000. running mean: -20.434873
# resetting env. episode reward total was -21.000000. running mean: -20.440524
# resetting env. episode reward total was -18.000000. running mean: -20.416119
# resetting env. episode reward total was -19.000000. running mean: -20.401958
# resetting env. episode reward total was -21.000000. running mean: -20.407938
# resetting env. episode reward total was -21.000000. running mean: -20.413859
# resetting env. episode reward total was -21.000000. running mean: -20.419720
# resetting env. episode reward total was -21.000000. running mean: -20.425523
# resetting env. episode reward total was -17.000000. running mean: -20.391268
# resetting env. episode reward total was -21.000000. running mean: -20.397355
# resetting env. episode reward total was -19.000000. running mean: -20.383381
# resetting env. episode reward total was -21.000000. running mean: -20.389548
# resetting env. episode reward total was -21.000000. running mean: -20.395652
# resetting env. episode reward total was -20.000000. running mean: -20.391696
# resetting env. episode reward total was -20.000000. running mean: -20.387779
# resetting env. episode reward total was -21.000000. running mean: -20.393901
# resetting env. episode reward total was -20.000000. running mean: -20.389962
# resetting env. episode reward total was -20.000000. running mean: -20.386062
# resetting env. episode reward total was -20.000000. running mean: -20.382202
# resetting env. episode reward total was -21.000000. running mean: -20.388380
# resetting env. episode reward total was -21.000000. running mean: -20.394496
# resetting env. episode reward total was -20.000000. running mean: -20.390551
# resetting env. episode reward total was -21.000000. running mean: -20.396645
# resetting env. episode reward total was -20.000000. running mean: -20.392679
# resetting env. episode reward total was -21.000000. running mean: -20.398752
# resetting env. episode reward total was -19.000000. running mean: -20.384765
# resetting env. episode reward total was -20.000000. running mean: -20.380917
# resetting env. episode reward total was -20.000000. running mean: -20.377108
# resetting env. episode reward total was -21.000000. running mean: -20.383337
# resetting env. episode reward total was -20.000000. running mean: -20.379503
# resetting env. episode reward total was -21.000000. running mean: -20.385708
# resetting env. episode reward total was -21.000000. running mean: -20.391851
# resetting env. episode reward total was -21.000000. running mean: -20.397933
# resetting env. episode reward total was -21.000000. running mean: -20.403953
# resetting env. episode reward total was -20.000000. running mean: -20.399914
# resetting env. episode reward total was -21.000000. running mean: -20.405915
# resetting env. episode reward total was -21.000000. running mean: -20.411856
# resetting env. episode reward total was -21.000000. running mean: -20.417737
# resetting env. episode reward total was -21.000000. running mean: -20.423560
# resetting env. episode reward total was -19.000000. running mean: -20.409324
# resetting env. episode reward total was -20.000000. running mean: -20.405231
# resetting env. episode reward total was -21.000000. running mean: -20.411179
# resetting env. episode reward total was -21.000000. running mean: -20.417067
# resetting env. episode reward total was -21.000000. running mean: -20.422896
# resetting env. episode reward total was -20.000000. running mean: -20.418667
# resetting env. episode reward total was -21.000000. running mean: -20.424480
# resetting env. episode reward total was -21.000000. running mean: -20.430236
# resetting env. episode reward total was -20.000000. running mean: -20.425933
# resetting env. episode reward total was -20.000000. running mean: -20.421674
# resetting env. episode reward total was -21.000000. running mean: -20.427457
# resetting env. episode reward total was -21.000000. running mean: -20.433183
# resetting env. episode reward total was -21.000000. running mean: -20.438851
# resetting env. episode reward total was -20.000000. running mean: -20.434462
# resetting env. episode reward total was -21.000000. running mean: -20.440118
# resetting env. episode reward total was -20.000000. running mean: -20.435717
# resetting env. episode reward total was -20.000000. running mean: -20.431359
# resetting env. episode reward total was -21.000000. running mean: -20.437046
# resetting env. episode reward total was -21.000000. running mean: -20.442675
# resetting env. episode reward total was -21.000000. running mean: -20.448249
# resetting env. episode reward total was -20.000000. running mean: -20.443766
# resetting env. episode reward total was -21.000000. running mean: -20.449328
# resetting env. episode reward total was -20.000000. running mean: -20.444835
# resetting env. episode reward total was -19.000000. running mean: -20.430387
# resetting env. episode reward total was -20.000000. running mean: -20.426083
# resetting env. episode reward total was -20.000000. running mean: -20.421822
# resetting env. episode reward total was -21.000000. running mean: -20.427604
# resetting env. episode reward total was -20.000000. running mean: -20.423328
# resetting env. episode reward total was -20.000000. running mean: -20.419095
# resetting env. episode reward total was -21.000000. running mean: -20.424904
# resetting env. episode reward total was -21.000000. running mean: -20.430655
# resetting env. episode reward total was -20.000000. running mean: -20.426348
# resetting env. episode reward total was -21.000000. running mean: -20.432085
# resetting env. episode reward total was -19.000000. running mean: -20.417764
# resetting env. episode reward total was -19.000000. running mean: -20.403586
# resetting env. episode reward total was -19.000000. running mean: -20.389550
# resetting env. episode reward total was -21.000000. running mean: -20.395655
# resetting env. episode reward total was -21.000000. running mean: -20.401698
# resetting env. episode reward total was -21.000000. running mean: -20.407681
# resetting env. episode reward total was -21.000000. running mean: -20.413604
# resetting env. episode reward total was -20.000000. running mean: -20.409468
# resetting env. episode reward total was -20.000000. running mean: -20.405374
# resetting env. episode reward total was -19.000000. running mean: -20.391320
# resetting env. episode reward total was -20.000000. running mean: -20.387407
# resetting env. episode reward total was -21.000000. running mean: -20.393533
# resetting env. episode reward total was -20.000000. running mean: -20.389597
# resetting env. episode reward total was -20.000000. running mean: -20.385701
# resetting env. episode reward total was -21.000000. running mean: -20.391844
# resetting env. episode reward total was -20.000000. running mean: -20.387926
# resetting env. episode reward total was -21.000000. running mean: -20.394047
# resetting env. episode reward total was -21.000000. running mean: -20.400106
# resetting env. episode reward total was -20.000000. running mean: -20.396105
# resetting env. episode reward total was -21.000000. running mean: -20.402144
# resetting env. episode reward total was -21.000000. running mean: -20.408123
# resetting env. episode reward total was -21.000000. running mean: -20.414041
# resetting env. episode reward total was -20.000000. running mean: -20.409901
# resetting env. episode reward total was -21.000000. running mean: -20.415802
# resetting env. episode reward total was -21.000000. running mean: -20.421644
# resetting env. episode reward total was -21.000000. running mean: -20.427427
# resetting env. episode reward total was -20.000000. running mean: -20.423153
# resetting env. episode reward total was -20.000000. running mean: -20.418922
# resetting env. episode reward total was -21.000000. running mean: -20.424732
# resetting env. episode reward total was -18.000000. running mean: -20.400485
# resetting env. episode reward total was -19.000000. running mean: -20.386480
# resetting env. episode reward total was -21.000000. running mean: -20.392615
# resetting env. episode reward total was -20.000000. running mean: -20.388689
# resetting env. episode reward total was -20.000000. running mean: -20.384802
# resetting env. episode reward total was -21.000000. running mean: -20.390954
# resetting env. episode reward total was -21.000000. running mean: -20.397045
# resetting env. episode reward total was -18.000000. running mean: -20.373074
# resetting env. episode reward total was -19.000000. running mean: -20.359344
# resetting env. episode reward total was -21.000000. running mean: -20.365750
# resetting env. episode reward total was -21.000000. running mean: -20.372093
# resetting env. episode reward total was -21.000000. running mean: -20.378372
# resetting env. episode reward total was -21.000000. running mean: -20.384588
# resetting env. episode reward total was -21.000000. running mean: -20.390742
# resetting env. episode reward total was -19.000000. running mean: -20.376835
# resetting env. episode reward total was -18.000000. running mean: -20.353066
# resetting env. episode reward total was -20.000000. running mean: -20.349536
# resetting env. episode reward total was -19.000000. running mean: -20.336040
# resetting env. episode reward total was -21.000000. running mean: -20.342680
# resetting env. episode reward total was -21.000000. running mean: -20.349253
# resetting env. episode reward total was -20.000000. running mean: -20.345761
# resetting env. episode reward total was -19.000000. running mean: -20.332303
# resetting env. episode reward total was -21.000000. running mean: -20.338980
# resetting env. episode reward total was -21.000000. running mean: -20.345590
# resetting env. episode reward total was -20.000000. running mean: -20.342134
# resetting env. episode reward total was -20.000000. running mean: -20.338713
# resetting env. episode reward total was -20.000000. running mean: -20.335326
# resetting env. episode reward total was -21.000000. running mean: -20.341973
# resetting env. episode reward total was -21.000000. running mean: -20.348553
# resetting env. episode reward total was -20.000000. running mean: -20.345067
# resetting env. episode reward total was -21.000000. running mean: -20.351617
# resetting env. episode reward total was -20.000000. running mean: -20.348100
# resetting env. episode reward total was -21.000000. running mean: -20.354619
# resetting env. episode reward total was -21.000000. running mean: -20.361073
# resetting env. episode reward total was -21.000000. running mean: -20.367463
# resetting env. episode reward total was -20.000000. running mean: -20.363788
# resetting env. episode reward total was -21.000000. running mean: -20.370150
# resetting env. episode reward total was -20.000000. running mean: -20.366449
# resetting env. episode reward total was -21.000000. running mean: -20.372784
# resetting env. episode reward total was -21.000000. running mean: -20.379056
# resetting env. episode reward total was -18.000000. running mean: -20.355266
# resetting env. episode reward total was -21.000000. running mean: -20.361713
# resetting env. episode reward total was -20.000000. running mean: -20.358096
# resetting env. episode reward total was -19.000000. running mean: -20.344515
# resetting env. episode reward total was -21.000000. running mean: -20.351070
# resetting env. episode reward total was -21.000000. running mean: -20.357559
# resetting env. episode reward total was -19.000000. running mean: -20.343983
# resetting env. episode reward total was -21.000000. running mean: -20.350544
# resetting env. episode reward total was -19.000000. running mean: -20.337038
# resetting env. episode reward total was -21.000000. running mean: -20.343668
# resetting env. episode reward total was -21.000000. running mean: -20.350231
# resetting env. episode reward total was -20.000000. running mean: -20.346729
# resetting env. episode reward total was -21.000000. running mean: -20.353262
# resetting env. episode reward total was -18.000000. running mean: -20.329729
# resetting env. episode reward total was -21.000000. running mean: -20.336432
# resetting env. episode reward total was -21.000000. running mean: -20.343067
# resetting env. episode reward total was -21.000000. running mean: -20.349637
# resetting env. episode reward total was -21.000000. running mean: -20.356140
# resetting env. episode reward total was -20.000000. running mean: -20.352579
# resetting env. episode reward total was -21.000000. running mean: -20.359053
# resetting env. episode reward total was -21.000000. running mean: -20.365463
# resetting env. episode reward total was -19.000000. running mean: -20.351808
# resetting env. episode reward total was -18.000000. running mean: -20.328290
# resetting env. episode reward total was -21.000000. running mean: -20.335007
# resetting env. episode reward total was -21.000000. running mean: -20.341657
# resetting env. episode reward total was -20.000000. running mean: -20.338240
# resetting env. episode reward total was -20.000000. running mean: -20.334858
# resetting env. episode reward total was -20.000000. running mean: -20.331509
# resetting env. episode reward total was -21.000000. running mean: -20.338194
# resetting env. episode reward total was -21.000000. running mean: -20.344812
# resetting env. episode reward total was -20.000000. running mean: -20.341364
# resetting env. episode reward total was -20.000000. running mean: -20.337951
# resetting env. episode reward total was -20.000000. running mean: -20.334571
# resetting env. episode reward total was -21.000000. running mean: -20.341225
# resetting env. episode reward total was -19.000000. running mean: -20.327813
# resetting env. episode reward total was -21.000000. running mean: -20.334535
# resetting env. episode reward total was -20.000000. running mean: -20.331190
# resetting env. episode reward total was -21.000000. running mean: -20.337878
# resetting env. episode reward total was -21.000000. running mean: -20.344499
# resetting env. episode reward total was -19.000000. running mean: -20.331054
# resetting env. episode reward total was -19.000000. running mean: -20.317743
# resetting env. episode reward total was -21.000000. running mean: -20.324566
# resetting env. episode reward total was -18.000000. running mean: -20.301320
# resetting env. episode reward total was -19.000000. running mean: -20.288307
# resetting env. episode reward total was -21.000000. running mean: -20.295424
# resetting env. episode reward total was -21.000000. running mean: -20.302470
# resetting env. episode reward total was -20.000000. running mean: -20.299445
# resetting env. episode reward total was -20.000000. running mean: -20.296451
# resetting env. episode reward total was -21.000000. running mean: -20.303486
# resetting env. episode reward total was -21.000000. running mean: -20.310451
# resetting env. episode reward total was -21.000000. running mean: -20.317347
# resetting env. episode reward total was -21.000000. running mean: -20.324173
# resetting env. episode reward total was -21.000000. running mean: -20.330932
# resetting env. episode reward total was -21.000000. running mean: -20.337622
# resetting env. episode reward total was -19.000000. running mean: -20.324246
# resetting env. episode reward total was -21.000000. running mean: -20.331004
# resetting env. episode reward total was -21.000000. running mean: -20.337694
# resetting env. episode reward total was -19.000000. running mean: -20.324317
# resetting env. episode reward total was -20.000000. running mean: -20.321073
# resetting env. episode reward total was -21.000000. running mean: -20.327863
# resetting env. episode reward total was -21.000000. running mean: -20.334584
# resetting env. episode reward total was -21.000000. running mean: -20.341238
# resetting env. episode reward total was -21.000000. running mean: -20.347826
# resetting env. episode reward total was -20.000000. running mean: -20.344348
# resetting env. episode reward total was -21.000000. running mean: -20.350904
# resetting env. episode reward total was -21.000000. running mean: -20.357395
# resetting env. episode reward total was -21.000000. running mean: -20.363821
# resetting env. episode reward total was -21.000000. running mean: -20.370183
# resetting env. episode reward total was -21.000000. running mean: -20.376481
# resetting env. episode reward total was -19.000000. running mean: -20.362716
# resetting env. episode reward total was -21.000000. running mean: -20.369089
# resetting env. episode reward total was -21.000000. running mean: -20.375398
# resetting env. episode reward total was -20.000000. running mean: -20.371644
# resetting env. episode reward total was -21.000000. running mean: -20.377928
# resetting env. episode reward total was -21.000000. running mean: -20.384149
# resetting env. episode reward total was -20.000000. running mean: -20.380307
# resetting env. episode reward total was -21.000000. running mean: -20.386504
# resetting env. episode reward total was -20.000000. running mean: -20.382639
# resetting env. episode reward total was -21.000000. running mean: -20.388813
# resetting env. episode reward total was -19.000000. running mean: -20.374924
# resetting env. episode reward total was -21.000000. running mean: -20.381175
# resetting env. episode reward total was -21.000000. running mean: -20.387363
# resetting env. episode reward total was -21.000000. running mean: -20.393490
# resetting env. episode reward total was -21.000000. running mean: -20.399555
# resetting env. episode reward total was -21.000000. running mean: -20.405559
# ...
# resetting env. episode reward total was -19.000000. running mean: -19.681368
# resetting env. episode reward total was -21.000000. running mean: -19.694554
# resetting env. episode reward total was -19.000000. running mean: -19.687608
# resetting env. episode reward total was -21.000000. running mean: -19.700732
# resetting env. episode reward total was -20.000000. running mean: -19.703725
# resetting env. episode reward total was -19.000000. running mean: -19.696688
# resetting env. episode reward total was -18.000000. running mean: -19.679721
# resetting env. episode reward total was -19.000000. running mean: -19.672924
# resetting env. episode reward total was -17.000000. running mean: -19.646194
# resetting env. episode reward total was -20.000000. running mean: -19.649733
# resetting env. episode reward total was -18.000000. running mean: -19.633235
# resetting env. episode reward total was -21.000000. running mean: -19.646903
# resetting env. episode reward total was -19.000000. running mean: -19.640434
# resetting env. episode reward total was -21.000000. running mean: -19.654030
# resetting env. episode reward total was -20.000000. running mean: -19.657489
# resetting env. episode reward total was -19.000000. running mean: -19.650914
# resetting env. episode reward total was -21.000000. running mean: -19.664405
# resetting env. episode reward total was -19.000000. running mean: -19.657761
# resetting env. episode reward total was -20.000000. running mean: -19.661184
# resetting env. episode reward total was -20.000000. running mean: -19.664572
# resetting env. episode reward total was -20.000000. running mean: -19.667926
# resetting env. episode reward total was -21.000000. running mean: -19.681247
# resetting env. episode reward total was -21.000000. running mean: -19.694434
# resetting env. episode reward total was -20.000000. running mean: -19.697490
# resetting env. episode reward total was -21.000000. running mean: -19.710515
# resetting env. episode reward total was -21.000000. running mean: -19.723410
# resetting env. episode reward total was -21.000000. running mean: -19.736176
# resetting env. episode reward total was -19.000000. running mean: -19.728814
# resetting env. episode reward total was -19.000000. running mean: -19.721526
# resetting env. episode reward total was -21.000000. running mean: -19.734311
# resetting env. episode reward total was -18.000000. running mean: -19.716967
# resetting env. episode reward total was -19.000000. running mean: -19.709798
# resetting env. episode reward total was -19.000000. running mean: -19.702700
# resetting env. episode reward total was -20.000000. running mean: -19.705673
# resetting env. episode reward total was -20.000000. running mean: -19.708616
# resetting env. episode reward total was -18.000000. running mean: -19.691530
# resetting env. episode reward total was -21.000000. running mean: -19.704615
# resetting env. episode reward total was -19.000000. running mean: -19.697568
# resetting env. episode reward total was -21.000000. running mean: -19.710593
# resetting env. episode reward total was -20.000000. running mean: -19.713487
# resetting env. episode reward total was -20.000000. running mean: -19.716352
# resetting env. episode reward total was -19.000000. running mean: -19.709188
# resetting env. episode reward total was -20.000000. running mean: -19.712097
# resetting env. episode reward total was -19.000000. running mean: -19.704976
# resetting env. episode reward total was -19.000000. running mean: -19.697926
# resetting env. episode reward total was -17.000000. running mean: -19.670947
# resetting env. episode reward total was -20.000000. running mean: -19.674237
# resetting env. episode reward total was -19.000000. running mean: -19.667495
# resetting env. episode reward total was -21.000000. running mean: -19.680820
# resetting env. episode reward total was -21.000000. running mean: -19.694012
# resetting env. episode reward total was -20.000000. running mean: -19.697072
# resetting env. episode reward total was -20.000000. running mean: -19.700101
# resetting env. episode reward total was -20.000000. running mean: -19.703100
# resetting env. episode reward total was -18.000000. running mean: -19.686069
# resetting env. episode reward total was -21.000000. running mean: -19.699208
# resetting env. episode reward total was -20.000000. running mean: -19.702216
# resetting env. episode reward total was -21.000000. running mean: -19.715194
# resetting env. episode reward total was -20.000000. running mean: -19.718042
# resetting env. episode reward total was -19.000000. running mean: -19.710862
# resetting env. episode reward total was -21.000000. running mean: -19.723753
# resetting env. episode reward total was -21.000000. running mean: -19.736515
# resetting env. episode reward total was -21.000000. running mean: -19.749150
# resetting env. episode reward total was -19.000000. running mean: -19.741659
# resetting env. episode reward total was -17.000000. running mean: -19.714242
# resetting env. episode reward total was -18.000000. running mean: -19.697100
# resetting env. episode reward total was -21.000000. running mean: -19.710129
# resetting env. episode reward total was -21.000000. running mean: -19.723027
# resetting env. episode reward total was -21.000000. running mean: -19.735797
# resetting env. episode reward total was -21.000000. running mean: -19.748439
# resetting env. episode reward total was -18.000000. running mean: -19.730955
# resetting env. episode reward total was -17.000000. running mean: -19.703645
# resetting env. episode reward total was -18.000000. running mean: -19.686609
# resetting env. episode reward total was -19.000000. running mean: -19.679743
# resetting env. episode reward total was -20.000000. running mean: -19.682945
# resetting env. episode reward total was -21.000000. running mean: -19.696116
# resetting env. episode reward total was -20.000000. running mean: -19.699155
# resetting env. episode reward total was -18.000000. running mean: -19.682163
# resetting env. episode reward total was -20.000000. running mean: -19.685341
# resetting env. episode reward total was -20.000000. running mean: -19.688488
# resetting env. episode reward total was -21.000000. running mean: -19.701603
# resetting env. episode reward total was -21.000000. running mean: -19.714587
# resetting env. episode reward total was -21.000000. running mean: -19.727441
# resetting env. episode reward total was -21.000000. running mean: -19.740167
# resetting env. episode reward total was -20.000000. running mean: -19.742765
# resetting env. episode reward total was -21.000000. running mean: -19.755338
# resetting env. episode reward total was -21.000000. running mean: -19.767784
# resetting env. episode reward total was -18.000000. running mean: -19.750106
# resetting env. episode reward total was -19.000000. running mean: -19.742605
# resetting env. episode reward total was -21.000000. running mean: -19.755179
# resetting env. episode reward total was -21.000000. running mean: -19.767627
# resetting env. episode reward total was -21.000000. running mean: -19.779951
# resetting env. episode reward total was -19.000000. running mean: -19.772152
# resetting env. episode reward total was -21.000000. running mean: -19.784430
# resetting env. episode reward total was -17.000000. running mean: -19.756586
# resetting env. episode reward total was -16.000000. running mean: -19.719020
# resetting env. episode reward total was -21.000000. running mean: -19.731830
# resetting env. episode reward total was -18.000000. running mean: -19.714511
# resetting env. episode reward total was -20.000000. running mean: -19.717366
# resetting env. episode reward total was -21.000000. running mean: -19.730193
# resetting env. episode reward total was -19.000000. running mean: -19.722891
# resetting env. episode reward total was -17.000000. running mean: -19.695662
# resetting env. episode reward total was -21.000000. running mean: -19.708705
# resetting env. episode reward total was -20.000000. running mean: -19.711618
# resetting env. episode reward total was -20.000000. running mean: -19.714502
# resetting env. episode reward total was -19.000000. running mean: -19.707357
# resetting env. episode reward total was -18.000000. running mean: -19.690283
# resetting env. episode reward total was -21.000000. running mean: -19.703381
# resetting env. episode reward total was -21.000000. running mean: -19.716347
# resetting env. episode reward total was -21.000000. running mean: -19.729183
# resetting env. episode reward total was -20.000000. running mean: -19.731891
# resetting env. episode reward total was -21.000000. running mean: -19.744573
# resetting env. episode reward total was -21.000000. running mean: -19.757127
# resetting env. episode reward total was -19.000000. running mean: -19.749556
# resetting env. episode reward total was -19.000000. running mean: -19.742060
# resetting env. episode reward total was -21.000000. running mean: -19.754639
# resetting env. episode reward total was -18.000000. running mean: -19.737093
# resetting env. episode reward total was -21.000000. running mean: -19.749722
# resetting env. episode reward total was -19.000000. running mean: -19.742225
# resetting env. episode reward total was -18.000000. running mean: -19.724803
# resetting env. episode reward total was -19.000000. running mean: -19.717555
# resetting env. episode reward total was -20.000000. running mean: -19.720379
# resetting env. episode reward total was -19.000000. running mean: -19.713175
# resetting env. episode reward total was -16.000000. running mean: -19.676043
# resetting env. episode reward total was -19.000000. running mean: -19.669283
# resetting env. episode reward total was -20.000000. running mean: -19.672590
# resetting env. episode reward total was -21.000000. running mean: -19.685864
# resetting env. episode reward total was -21.000000. running mean: -19.699006
# resetting env. episode reward total was -21.000000. running mean: -19.712016
# resetting env. episode reward total was -20.000000. running mean: -19.714895
# resetting env. episode reward total was -20.000000. running mean: -19.717747
# resetting env. episode reward total was -21.000000. running mean: -19.730569
# resetting env. episode reward total was -20.000000. running mean: -19.733263
# resetting env. episode reward total was -20.000000. running mean: -19.735931
# resetting env. episode reward total was -21.000000. running mean: -19.748571
# resetting env. episode reward total was -19.000000. running mean: -19.741086
# resetting env. episode reward total was -21.000000. running mean: -19.753675
# resetting env. episode reward total was -19.000000. running mean: -19.746138
# resetting env. episode reward total was -19.000000. running mean: -19.738677
# resetting env. episode reward total was -21.000000. running mean: -19.751290
# resetting env. episode reward total was -20.000000. running mean: -19.753777
# resetting env. episode reward total was -19.000000. running mean: -19.746239
# resetting env. episode reward total was -18.000000. running mean: -19.728777
# resetting env. episode reward total was -21.000000. running mean: -19.741489
# resetting env. episode reward total was -20.000000. running mean: -19.744074
# resetting env. episode reward total was -21.000000. running mean: -19.756633
# resetting env. episode reward total was -20.000000. running mean: -19.759067
# resetting env. episode reward total was -19.000000. running mean: -19.751476
# resetting env. episode reward total was -19.000000. running mean: -19.743962
# resetting env. episode reward total was -20.000000. running mean: -19.746522
# resetting env. episode reward total was -18.000000. running mean: -19.729057
# resetting env. episode reward total was -19.000000. running mean: -19.721766
# resetting env. episode reward total was -17.000000. running mean: -19.694549
# resetting env. episode reward total was -20.000000. running mean: -19.697603
# resetting env. episode reward total was -19.000000. running mean: -19.690627
# resetting env. episode reward total was -18.000000. running mean: -19.673721
# resetting env. episode reward total was -20.000000. running mean: -19.676984
# resetting env. episode reward total was -21.000000. running mean: -19.690214
# resetting env. episode reward total was -20.000000. running mean: -19.693312
# resetting env. episode reward total was -21.000000. running mean: -19.706379
# resetting env. episode reward total was -21.000000. running mean: -19.719315
# resetting env. episode reward total was -20.000000. running mean: -19.722122
# resetting env. episode reward total was -21.000000. running mean: -19.734900
# resetting env. episode reward total was -18.000000. running mean: -19.717551
# resetting env. episode reward total was -20.000000. running mean: -19.720376
# resetting env. episode reward total was -20.000000. running mean: -19.723172
# resetting env. episode reward total was -21.000000. running mean: -19.735940
# resetting env. episode reward total was -17.000000. running mean: -19.708581
# resetting env. episode reward total was -20.000000. running mean: -19.711495
# resetting env. episode reward total was -20.000000. running mean: -19.714380
# resetting env. episode reward total was -19.000000. running mean: -19.707236
# resetting env. episode reward total was -19.000000. running mean: -19.700164
# resetting env. episode reward total was -21.000000. running mean: -19.713162
# resetting env. episode reward total was -19.000000. running mean: -19.706031
# resetting env. episode reward total was -20.000000. running mean: -19.708971
# resetting env. episode reward total was -21.000000. running mean: -19.721881
# resetting env. episode reward total was -16.000000. running mean: -19.684662
# resetting env. episode reward total was -21.000000. running mean: -19.697815
# resetting env. episode reward total was -20.000000. running mean: -19.700837
# resetting env. episode reward total was -18.000000. running mean: -19.683829
# resetting env. episode reward total was -19.000000. running mean: -19.676991
# resetting env. episode reward total was -20.000000. running mean: -19.680221
# resetting env. episode reward total was -19.000000. running mean: -19.673418
# resetting env. episode reward total was -19.000000. running mean: -19.666684
# resetting env. episode reward total was -19.000000. running mean: -19.660017
# resetting env. episode reward total was -21.000000. running mean: -19.673417
# resetting env. episode reward total was -20.000000. running mean: -19.676683
# resetting env. episode reward total was -18.000000. running mean: -19.659916
# resetting env. episode reward total was -18.000000. running mean: -19.643317
# resetting env. episode reward total was -20.000000. running mean: -19.646884
# resetting env. episode reward total was -18.000000. running mean: -19.630415
# resetting env. episode reward total was -21.000000. running mean: -19.644111
# resetting env. episode reward total was -19.000000. running mean: -19.637670
# resetting env. episode reward total was -19.000000. running mean: -19.631293
# resetting env. episode reward total was -19.000000. running mean: -19.624980
# resetting env. episode reward total was -21.000000. running mean: -19.638730
# resetting env. episode reward total was -19.000000. running mean: -19.632343
# resetting env. episode reward total was -20.000000. running mean: -19.636020
# resetting env. episode reward total was -18.000000. running mean: -19.619659
# resetting env. episode reward total was -19.000000. running mean: -19.613463
# resetting env. episode reward total was -21.000000. running mean: -19.627328
# resetting env. episode reward total was -17.000000. running mean: -19.601055
# resetting env. episode reward total was -18.000000. running mean: -19.585044
# resetting env. episode reward total was -19.000000. running mean: -19.579194
# resetting env. episode reward total was -17.000000. running mean: -19.553402
# resetting env. episode reward total was -20.000000. running mean: -19.557868
# resetting env. episode reward total was -20.000000. running mean: -19.562289
# resetting env. episode reward total was -19.000000. running mean: -19.556666

# %%
env.close()
