# %%
import pandas as pd
import numpy as np
from scipy.sparse import csr_matrix

# %%
df = pd.read_csv('news_headlines.csv')
uw_df = pd.read_csv('useless_words.csv')

# %%
def represents_number(s):
    try:
        float(s)
        return True
    except ValueError:
        return False

def convert_word(s):
    # take out useless characters
    s = s.translate({ord(c): None for c in '!@#:;'})
    # plural
    if len(s) > 0 and s[len(s)-1] == 's':
        s = s[:-1]
    return s

# %%
useless_words = uw_df.useless_words.values.tolist()

bag_of_words = {}
for headline in df.headline_text:
    for word in headline.split(' '):
        word = convert_word(word)
        if (len(word) == 0):
            continue
        # useless words
        if (word in useless_words):
            continue
        # money
        if (word[0] == '$'):
            continue
        # number
        if (represents_number(word)):
            continue
        
        if (word in bag_of_words):
            bag_of_words[word] += 1
        else:
            bag_of_words[word] = 1

# %%
print(len(bag_of_words))
print(bag_of_words.keys())
# Out:
# 69069
# ...

# %%
keys = list(bag_of_words.keys())

matrix = np.zeros((len(bag_of_words),len(df.headline_text)), dtype=np.int8)
#vectors = pd.DataFrame(np.zeros(len(bag_of_words),len(df.headline_text)))
#print(vectors)
'''
for headline in df.headline_text:
    v = [0] * len(bag_of_words)
    for word in headline.split(' '):
        # take out useless characters
        word = word.translate({ord(c): None for c in '!@#:;'})
        if (len(word) == 0):
            continue
        # plural
        if len(word) > 0 and word[len(word)-1] == 's':
            word = word[:-1]
        if (word in bag_of_words):
            v[keys.index(word)] = 1'''
# Out:
# "\nfor headline in df.headline_text:\n    v = [0] * len(bag_of_words)\n    for word in headline.split(' '):\n        # take out useless characters\n        word = word.translate({ord(c): None for c in '!@#:;'})\n        if (len(word) == 0):\n            continue\n        # plural\n        if len(word) > 0 and word[len(word)-1] == 's':\n            word = word[:-1]\n        if (word in bag_of_words):\n            v[keys.index(word)] = 1"
